# %% [markdown]
# <img src="https://www.rp.edu.sg/images/default-source/default-album/rp-logo.png" width="200" alt="Republic Polytechnic"/>
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/koayst-rplesson/SST_DP2025/blob/main/L01/L01_Exercise_Answer.ipynb)

# %%
# %%capture --no-stderr
# %pip install --quiet -U nltk

# %%
# print module version(s)

import nltk
print (nltk.__version__)
# Out:
# 3.9.1

# %%
# download and install the resource 
# https://www.nltk.org/api/nltk.tokenize.punkt.html
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\koay_seng_tian\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\koay_seng_tian\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\koay_seng_tian\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\koay_seng_tian\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # Lesson 01 Exercise
#
# Given the text below, what are the preprocessing techniques you could apply?
#
# "Generative AI is revolutionizing many industries by automating creative tasks such as writing, designing, and even composing music. These models, like GPT and DALL·E, learn from vast amounts of data to produce original content that mimics human output. However, the ethical implications of this technology, including concerns about bias and intellectual property, are raising important debates. As generative AI continues to evolve, it is crucial for researchers and developers to address these challenges to ensure responsible and fair use."

# %%
text = """
Generative AI is revolutionizing many industries by automating creative tasks such as writing, designing, and even composing music. 
These models, like GPT and DALL·E, learn from vast amounts of data to produce original content that mimics human output. 
However, the ethical implications of this technology, including concerns about bias and intellectual property, are raising important debates. 
As generative AI continues to evolve, it is crucial for researchers and developers to address these challenges to ensure responsible and fair use.
"""

# %%
# pprint, short for "pretty-print," is a Python module and function that helps print data structures 
# (like lists, dictionaries, etc.) in a more readable and formatted way

from pprint import pprint

# %% [markdown]
# ## Tokenization
#
# Tokenization is the process of splitting the text into individual words or sentences.

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

word_tokens = word_tokenize(text)  # Word-level tokenization
sentence_tokens = sent_tokenize(text)  # Sentence-level tokenization

pprint(word_tokens)
print()
pprint(sentence_tokens)
# Out:
# ['Generative',
#  'AI',
#  'is',
#  'revolutionizing',
#  'many',
#  'industries',
#  'by',
#  'automating',
#  'creative',
#  'tasks',
#  'such',
#  'as',
#  'writing',
#  ',',
#  'designing',
#  ',',
#  'and',
#  'even',
#  'composing',
#  'music',
#  '.',
#  'These',
#  'models',
#  ',',
#  'like',
#  'GPT',
#  'and',
#  'DALL·E',
#  ',',
#  'learn',
#  'from',
#  'vast',
#  'amounts',
#  'of',
#  'data',
#  'to',
#  'produce',
#  'original',
#  'content',
#  'that',
#  'mimics',
#  'human',
#  'output',
#  '.',
#  'However',
#  ',',
#  'the',
#  'ethical',
#  'implications',
#  'of',
#  'this',
#  'technology',
#  ',',
#  'including',
#  'concerns',
#  'about',
#  'bias',
#  'and',
#  'intellectual',
#  'property',
#  ',',
#  'are',
#  'raising',
#  'important',
#  'debates',
#  '.',
#  'As',
#  'generative',
#  'AI',
#  'continues',
#  'to',
#  'evolve',
#  ',',
#  'it',
#  'is',
#  'crucial',
#  'for',
#  'researchers',
#  'and',
#  'developers',
#  'to',
#  'address',
#  'these',
#  'challenges',
#  'to',
#  'ensure',
#  'responsible',
#  'and',
#  'fair',
#  'use',
#  '.']
#
# ['\n'
#  'Generative AI is revolutionizing many industries by automating creative '
#  'tasks such as writing, designing, and even composing music.',
#  'These models, like GPT and DALL·E, learn from vast amounts of data to '
#  'produce original content that mimics human output.',
#  'However, the ethical implications of this technology, including concerns '
#  'about bias and intellectual property, are raising important debates.',
#  'As generative AI continues to evolve, it is crucial for researchers and '
#  'developers to address these challenges to ensure responsible and fair use.']

# %% [markdown]
# ## Part-of-Speech (POS) Tagging
#
# POS tagging involves assigning a part of speech (noun, verb, adjective, etc.) to each word in the tokenized text.

# %%
from nltk import pos_tag

pos_tags = pos_tag(word_tokens)  # Apply POS tagging to word tokens

pprint(pos_tags)
# Out:
# [('Generative', 'JJ'),
#  ('AI', 'NNP'),
#  ('is', 'VBZ'),
#  ('revolutionizing', 'VBG'),
#  ('many', 'JJ'),
#  ('industries', 'NNS'),
#  ('by', 'IN'),
#  ('automating', 'VBG'),
#  ('creative', 'JJ'),
#  ('tasks', 'NNS'),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('writing', 'NN'),
#  (',', ','),
#  ('designing', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('even', 'RB'),
#  ('composing', 'VBG'),
#  ('music', 'NN'),
#  ('.', '.'),
#  ('These', 'DT'),
#  ('models', 'NNS'),
#  (',', ','),
#  ('like', 'IN'),
#  ('GPT', 'NNP'),
#  ('and', 'CC'),
#  ('DALL·E', 'NNP'),
#  (',', ','),
#  ('learn', 'NN'),
#  ('from', 'IN'),
#  ('vast', 'JJ'),
#  ('amounts', 'NNS'),
#  ('of', 'IN'),
#  ('data', 'NNS'),
#  ('to', 'TO'),
#  ('produce', 'VB'),
#  ('original', 'JJ'),
#  ('content', 'NN'),
#  ('that', 'IN'),
#  ('mimics', 'NNS'),
#  ('human', 'JJ'),
#  ('output', 'NN'),
#  ('.', '.'),
#  ('However', 'RB'),
#  (',', ','),
#  ('the', 'DT'),
#  ('ethical', 'JJ'),
#  ('implications', 'NNS'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('technology', 'NN'),
#  (',', ','),
#  ('including', 'VBG'),
#  ('concerns', 'NNS'),
#  ('about', 'IN'),
#  ('bias', 'NN'),
#  ('and', 'CC'),
#  ('intellectual', 'JJ'),
#  ('property', 'NN'),
#  (',', ','),
#  ('are', 'VBP'),
#  ('raising', 'VBG'),
#  ('important', 'JJ'),
#  ('debates', 'NNS'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('generative', 'JJ'),
#  ('AI', 'NNP'),
#  ('continues', 'VBZ'),
#  ('to', 'TO'),
#  ('evolve', 'VB'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('crucial', 'JJ'),
#  ('for', 'IN'),
#  ('researchers', 'NNS'),
#  ('and', 'CC'),
#  ('developers', 'NNS'),
#  ('to', 'TO'),
#  ('address', 'VB'),
#  ('these', 'DT'),
#  ('challenges', 'NNS'),
#  ('to', 'TO'),
#  ('ensure', 'VB'),
#  ('responsible', 'JJ'),
#  ('and', 'CC'),
#  ('fair', 'JJ'),
#  ('use', 'NN'),
#  ('.', '.')]

# %% [markdown]
# ## Stemming
#
# Stemming reduces words to their root form by removing suffixes (e.g., "revolutionizing" becomes "revolution").

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in word_tokens]

pprint(stemmed_words)
# Out:
# ['gener',
#  'ai',
#  'is',
#  'revolution',
#  'mani',
#  'industri',
#  'by',
#  'autom',
#  'creativ',
#  'task',
#  'such',
#  'as',
#  'write',
#  ',',
#  'design',
#  ',',
#  'and',
#  'even',
#  'compos',
#  'music',
#  '.',
#  'these',
#  'model',
#  ',',
#  'like',
#  'gpt',
#  'and',
#  'dall·',
#  ',',
#  'learn',
#  'from',
#  'vast',
#  'amount',
#  'of',
#  'data',
#  'to',
#  'produc',
#  'origin',
#  'content',
#  'that',
#  'mimic',
#  'human',
#  'output',
#  '.',
#  'howev',
#  ',',
#  'the',
#  'ethic',
#  'implic',
#  'of',
#  'thi',
#  'technolog',
#  ',',
#  'includ',
#  'concern',
#  'about',
#  'bia',
#  'and',
#  'intellectu',
#  'properti',
#  ',',
#  'are',
#  'rais',
#  'import',
#  'debat',
#  '.',
#  'as',
#  'gener',
#  'ai',
#  'continu',
#  'to',
#  'evolv',
#  ',',
#  'it',
#  'is',
#  'crucial',
#  'for',
#  'research',
#  'and',
#  'develop',
#  'to',
#  'address',
#  'these',
#  'challeng',
#  'to',
#  'ensur',
#  'respons',
#  'and',
#  'fair',
#  'use',
#  '.']

# %% [markdown]
# ## Lemmatization
#
# Lemmatization reduces words to their base or dictionary form (lemma), but considers the context (e.g., "better" becomes "good").

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word, pos='v') for word in word_tokens]  # 'v' is for verb

pprint(lemmatized_words)
# Out:
# ['Generative',
#  'AI',
#  'be',
#  'revolutionize',
#  'many',
#  'industries',
#  'by',
#  'automate',
#  'creative',
#  'task',
#  'such',
#  'as',
#  'write',
#  ',',
#  'design',
#  ',',
#  'and',
#  'even',
#  'compose',
#  'music',
#  '.',
#  'These',
#  'model',
#  ',',
#  'like',
#  'GPT',
#  'and',
#  'DALL·E',
#  ',',
#  'learn',
#  'from',
#  'vast',
#  'amount',
#  'of',
#  'data',
#  'to',
#  'produce',
#  'original',
#  'content',
#  'that',
#  'mimic',
#  'human',
#  'output',
#  '.',
#  'However',
#  ',',
#  'the',
#  'ethical',
#  'implications',
#  'of',
#  'this',
#  'technology',
#  ',',
#  'include',
#  'concern',
#  'about',
#  'bias',
#  'and',
#  'intellectual',
#  'property',
#  ',',
#  'be',
#  'raise',
#  'important',
#  'debate',
#  '.',
#  'As',
#  'generative',
#  'AI',
#  'continue',
#  'to',
#  'evolve',
#  ',',
#  'it',
#  'be',
#  'crucial',
#  'for',
#  'researchers',
#  'and',
#  'developers',
#  'to',
#  'address',
#  'these',
#  'challenge',
#  'to',
#  'ensure',
#  'responsible',
#  'and',
#  'fair',
#  'use',
#  '.']

# %% [markdown]
# ## Stop Words Removals
#
# Stop words are common words like "is", "the", and "and" that are often removed because they carry little meaningful information.

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
filtered_words = [word for word in word_tokens if word.lower() not in stop_words]

pprint(filtered_words)
# Out:
# ['Generative',
#  'AI',
#  'revolutionizing',
#  'many',
#  'industries',
#  'automating',
#  'creative',
#  'tasks',
#  'writing',
#  ',',
#  'designing',
#  ',',
#  'even',
#  'composing',
#  'music',
#  '.',
#  'models',
#  ',',
#  'like',
#  'GPT',
#  'DALL·E',
#  ',',
#  'learn',
#  'vast',
#  'amounts',
#  'data',
#  'produce',
#  'original',
#  'content',
#  'mimics',
#  'human',
#  'output',
#  '.',
#  'However',
#  ',',
#  'ethical',
#  'implications',
#  'technology',
#  ',',
#  'including',
#  'concerns',
#  'bias',
#  'intellectual',
#  'property',
#  ',',
#  'raising',
#  'important',
#  'debates',
#  '.',
#  'generative',
#  'AI',
#  'continues',
#  'evolve',
#  ',',
#  'crucial',
#  'researchers',
#  'developers',
#  'address',
#  'challenges',
#  'ensure',
#  'responsible',
#  'fair',
#  'use',
#  '.']

# %% [markdown]
# ## Chunking
#
# Chunking groups words into phrases based on POS tags, like noun phrases (NP) or verb phrases (VP).

# %%
import nltk
from nltk.tokenize import MWETokenizer

# Define multi-word expressions (phrases you want to treat as single tokens)
mwe = [('Generative', 'AI'), ('generative', 'AI')]

# Initialize the MWE tokenizer
tokenizer = MWETokenizer(mwe)

# Tokenize the text
tokens = tokenizer.tokenize(text.split())

pprint(tokens)
# Out:
# ['Generative_AI',
#  'is',
#  'revolutionizing',
#  'many',
#  'industries',
#  'by',
#  'automating',
#  'creative',
#  'tasks',
#  'such',
#  'as',
#  'writing,',
#  'designing,',
#  'and',
#  'even',
#  'composing',
#  'music.',
#  'These',
#  'models,',
#  'like',
#  'GPT',
#  'and',
#  'DALL·E,',
#  'learn',
#  'from',
#  'vast',
#  'amounts',
#  'of',
#  'data',
#  'to',
#  'produce',
#  'original',
#  'content',
#  'that',
#  'mimics',
#  'human',
#  'output.',
#  'However,',
#  'the',
#  'ethical',
#  'implications',
#  'of',
#  'this',
#  'technology,',
#  'including',
#  'concerns',
#  'about',
#  'bias',
#  'and',
#  'intellectual',
#  'property,',
#  'are',
#  'raising',
#  'important',
#  'debates.',
#  'As',
#  'generative_AI',
#  'continues',
#  'to',
#  'evolve,',
#  'it',
#  'is',
#  'crucial',
#  'for',
#  'researchers',
#  'and',
#  'developers',
#  'to',
#  'address',
#  'these',
#  'challenges',
#  'to',
#  'ensure',
#  'responsible',
#  'and',
#  'fair',
#  'use.']

# %% [markdown]
# ## Summary of Steps:
#
# 1. Tokenize the paragraph into words or sentences.
# 2. Apply POS tagging to the word tokens to label each word with its part of speech.
# 3. Use Stemming to reduce each word to its root form.
# 4. Use Lemmatization to convert each word to its base form, considering context.
# 5. Remove stop words to filter out common words that don’t add much meaning.
# 6. Perform Chunking to group tokens into syntactic phrases, like noun phrases or verb phrases.
#
# These techniques will help you explore different aspects of text preprocessing and syntactic analysis.
