# %% [markdown]
# <img src="https://www.rp.edu.sg/images/default-source/default-album/rp-logo.png" width="200" alt="Republic Polytechnic"/>
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/koayst-rplesson/SST_DP2025/blob/main/Day_02/L14/L14-02-streamlit-chat-history.ipynb)

# %%
# %%capture --no-stderr
# !pip install -q streamlit

# %%
# %%writefile app.py

import streamlit as st

st.title ("Echo Bot")

# Initialize chat history
if "messages" not in st.session_state:
    st.session_state.messages = []

#TODO: display chat messages from histroy on app rerun

# react to user input
if prompt := st.chat_input("What is up"):
    #Display user message in chat message container
    with st.chat_message("user"):
        st.markdown(prompt)
    #TODO: add user message to chat history


response = f"Echo: {prompt}"
# Display assistant response in chat message container
with st.chat_message("assistant"):
    st.markdown(response)
#TODO: Add assistant response to chat history
# Out:
# Writing app.py

# %% [markdown]
# Localtunnel is like a magic portal that lets the whole internet peek at what’s on your personal computer. Or boringly, it allows you to share your local server to the web. We’ll use it to expose the Streamlit app to the internet.

# %%
# !npm install localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋
# added 22 packages in 5s
# ⠋
# ⠋3 packages are looking for funding
# ⠋  run `npm fund` for details
# ⠋

# %% [markdown]
# **Run the Streamlit App and Expose it with Localtunnel**
#
#
# Finally, we run the Streamlit app and use Localtunnel to expose it. The following commands start the Streamlit server and then start Localtunnel to forward the server port to a public URL.

# %%
# !streamlit run app.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 35.231.186.224
# ⠙your url is: https://angry-kids-poke.loca.lt
