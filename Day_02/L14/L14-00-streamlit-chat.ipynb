# %% [markdown]
# <img src="https://www.rp.edu.sg/images/default-source/default-album/rp-logo.png" width="200" alt="Republic Polytechnic"/>
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/koayst-rplesson/SST_DP2025/blob/main/Day_02/L14/L14-00-streamlit-chat.ipynb)

# %%
# !pip install -q streamlit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 22.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 31.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.3 MB/s eta 0:00:00

# %%
# %%writefile app.py

import streamlit as st
import numpy as np

#TODO: Add a chat message container and display a message, "Hello...", and plot a bar_chart
# Out:
# Overwriting app.py

# %% [markdown]
# Localtunnel is like a magic portal that lets the whole internet peek at what’s on your personal computer. Or boringly, it allows you to share your local server to the web. We’ll use it to expose the Streamlit app to the internet.

# %%
# !npm install localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦
# up to date, audited 23 packages in 1s
# ⠦
# ⠦3 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# 2 moderate severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# ⠦

# %% [markdown]
# **Run the Streamlit App and Expose it with Localtunnel**
#
#
# Finally, we run the Streamlit app and use Localtunnel to expose it. The following commands start the Streamlit server and then start Localtunnel to forward the server port to a public URL.

# %%
# !streamlit run app.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# y
# 34.83.71.192
# ⠙⠹⠸⠼⠴⠦Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y) y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙your url is: https://six-zoos-sit.loca.lt
